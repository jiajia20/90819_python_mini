# %%
from GoogleNews import GoogleNews
googlenews = GoogleNews()

googlenews = GoogleNews(lang='en')
googlenews.set_time_range('02/03/2023','04/03/2023')
googlenews.get_news('Ohio Train Derailment')

# %%
result  = googlenews.results()

# %%
type(result)
len(result)
# Out:
# 102

# %%
import pandas as pd

# %%
# turn list into dataframe
df = pd.DataFrame(result)
df.head()
# Out:
#                                                title  desc        date  \
# 0  Tracking the Chemicals in the East Palestine, ...  None  3 days ago
# 1  Why tracking these pollution indicators is key...  None  2 days ago
# 2  Rail CEO repeats derailment apologies before O...  None  2 days ago
# 3  Norfolk Southern CEO set to testify before Ohi...  None  2 days ago
# 4  Ohio train derailment: Alan Shaw resists two-p...  None  2 days ago
#
#                     datetime  \
# 0 2023-04-17 15:52:03.788877
# 1 2023-04-18 15:52:03.789142
# 2 2023-04-18 15:52:03.789441
# 3 2023-04-18 15:52:03.789690
# 4 2023-04-18 15:52:03.789927
#
#                                                 link  \
# 0  news.google.com/./articles/CBMiUWh0dHBzOi8vd3d...
# 1  news.google.com/./articles/CBMifGh0dHBzOi8vd3d...
# 2  news.google.com/./articles/CBMiYmh0dHBzOi8vYXB...
# 3  news.google.com/./articles/CBMiXmh0dHBzOi8vd3d...
# 4  news.google.com/./articles/CBMikgFodHRwczovL3d...
#
#                                                  img                  media  \
# 0  https://lh3.googleusercontent.com/tDFSwtr61ZRe...     The New York Times
# 1  https://lh3.googleusercontent.com/evQbdgl9S9__...           PBS NewsHour
# 2  https://lh3.googleusercontent.com/proxy/MnHUB1...   The Associated Press
# 3  https://lh3.googleusercontent.com/proxy/7nSVWQ...               Fox News
# 4  https://lh3.googleusercontent.com/proxy/dTom4j...  The Columbus Dispatch
#
#    site
# 0  None
# 1  None
# 2  None
# 3  None
# 4  None

# %%
# sort by date
df.sort_values(by=['date'], inplace=True, ascending=True)
df.head()
# Out:
#                                                 title  desc            date  \
# 10  In Ohio, Regulators Are Letting The Polluter G...  None     10 days ago
# 41  Health First Joins Regional Coalition to Drill...  None  11 minutes ago
# 26  Norfolk Southern train derails in Pittsburgh 2...  None     12 days ago
# 22  Spurred to action: Derailments prompt look at ...  None    19 hours ago
# 9   Work on 2nd set of railroad tracks in East Pal...  None    19 hours ago
#
#                      datetime  \
# 10 2023-04-10 15:52:03.791318
# 41 2023-04-20 15:41:03.798276
# 26 2023-04-08 15:52:03.794917
# 22 2023-04-19 20:52:03.794047
# 9  2023-04-19 20:52:03.791086
#
#                                                  link  \
# 10  news.google.com/./articles/CBMiZ2h0dHBzOi8vd3d...
# 41  news.google.com/./articles/CBMie2h0dHBzOi8vc3B...
# 26  news.google.com/./articles/CBMiSWh0dHBzOi8vYWJ...
# 22  news.google.com/./articles/CBMikAFodHRwczovL3d...
# 9   news.google.com/./articles/CBMijQFodHRwczovL3d...
#
#                                                   img                media  \
# 10  https://lh3.googleusercontent.com/bG0RhWRdQ-jk...             HuffPost
# 41  https://encrypted-tbn2.gstatic.com/faviconV2?u...  SpaceCoastDaily.com
# 26  https://encrypted-tbn3.gstatic.com/faviconV2?u...               WLS-TV
# 22  https://encrypted-tbn2.gstatic.com/faviconV2?u...         Detroit News
# 9   https://lh3.googleusercontent.com/proxy/7qbFjS...             WKBN.com
#
#     site
# 10  None
# 41  None
# 26  None
# 22  None
# 9   None

# %%
print(googlenews.getVersion())
# Out:
# 1.6.7
